# %%
from darkflow.net.build import TFNet
import numpy as np
import math
import cv2
import os
import json
import base64
import requests
import skvideo.io
import PIL
import sys


def dectect_cars_per_image(cfg, weights, im):
    #demo purpose
    init_url='https://api.belairdirect.com/quickquote-blr/initDataContext?company=BELAIR&province=QC&language=EN&distributor=BEL&platform=desktop&partnershipId='
    headers = {}
    headers['Origin'] = 'https://apps.belairdirect.com'
    headers['Referer'] = 'https://apps.belairdirect.com/quick-quote/desktop/index.html?prov=qc&lang=en&intcid=homepage'
    params = {}
    params['distributor'] = 'BEL'
    params['company'] = 'BELAIR'
    params['province'] = 'QC'
    params['language'] = 'EN'
    params['emailAddress'] = ''
    params['licenceNumber'] = ''
    params['firstNameLicence'] = ''
    params['year'] = '2012'
    #params['make'] = 'HONDA'
    #params['model'] = '021001'
    params['distanceWorkSchool'] = '10'
    params['annualKm'] = '14000'
    params['gender'] = 'M'
    params['firstName'] = 'test'
    params['lastName'] = 'test'
    params['dateOfbirthYear'] = '1996'
    params['dateOfbirthMonth'] = '12'
    params['dateOfbirthDay'] = '12'
    params['homePhoneNumber'] = '514-555-1212'
    params['postalCode'] = 'H2W 1X9'
    params['firstLicencedAt'] = '18'
    params['yearsWithCurrentInsurer'] = '1'
    params['marketingConsent'] = 'false'
    params['creditScore'] = '0'
    params['otherAntiTheftDeviceIndicator'] = 'false'
    valid_makes = ['VOLKSWAGEN','FORD','DODGE','HONDA',
        'TOYOTA','TOYOTA','MAZDA','BMW','NISSAN','HYUNDAI']
    valid_models = ['Golf', 'F150', 'Grand Caravan','CR-V',
        'RAV-4','Camry','MAZDA3','328i','Altima','Elantra']
    valid_code =['968900','355801','266200','027101','755700',
        '045002','758600','903501','091005','052806']
    qq_price = {}
    #since we only use once
    mock_premium = ['2611.00',
                    '3171.00',
                    '2286.00',
                    '2825.00',
                    '2872.00',
                    '3036.00',
                    '2420.00',
                    '3701.00',
                    '2657.00',
                    '3204.00']
    index = 0
    for model in valid_models:
        #resp = requests.get(url=init_url,headers=headers)
        #policyVersionId =json.loads(resp.content.decode("utf-8"))['body']['policyVersionId']
        #params['policyVersionId'] = policyVersionId
        params['make'] = valid_makes[index]
        params['model'] = valid_code[index]
        #response = requests.get(url='https://api.belairdirect.com/quickquote-blr/getPrice',
        #    params=params, headers=headers)
        #premium = json.loads(response.content.decode("utf-8"))['body']['vehicles'][0]['offers']['CUSTOM']['offerDetails']['priceYearly']
        #print(valid_makes[index] +valid_code[index] + ':' + premium)
        #qq_price[valid_models[index]] = premium


        qq_price[valid_models[index]] = mock_premium[index]
        index += 1

    options = {"model": cfg, "load": weights, "threshold": 0.6}


    
    #loading yolo model
    tfnet = TFNet(options)
    
    imgcv = im
    
    boxes = tfnet.return_predict(imgcv)
    print(boxes)
    
    h, w, _ = imgcv.shape
    car_list = []
    car_num = 1
    for b in boxes:
        left = b['topleft']['x']
        right = b['bottomright']['x']
        top = b['topleft']['y']
        bot = b['bottomright']['y']
        mess = b['label']
        confidence = b['confidence']
        thick = int((h + w) // 300)

        #output the image box
        response = 'Cannot recognize a car.'
        print_text = 'null'
        if mess == 'car':
            crop = imgcv[top:bot,left:right]
            car_path = 'test/out/tmp/tmp.jpg'
            cv2.imwrite(car_path,crop)
            car_num += 1
            #post, getting result from car model
            with open(car_path, "rb") as image_file:

                encoded_string = base64.b64encode(image_file.read())
                url ='http://52.168.131.37:8080/predict/car_model2.0'
                data= encoded_string
                headers = {}
                headers['Content-Type'] = 'application/json'
                resp = requests.post(url=url, data=json.dumps(data.decode("utf-8")),headers=headers)
                response = json.loads(resp.content.decode("utf-8"))['top5_results']['top1']
                #response = json.loads(resp.content.decode("utf-8"))['Make'] + ' ' + json.loads(resp.content.decode("utf-8"))['Model'] + ':'
                #year_list = json.loads(resp.content.decode("utf-8"))['Year']
                #response += year_list[-1]
            os.remove(car_path)
            #car_list.append(json.loads(resp.content.decode("utf-8"))['Make'] + ' ' + json.loads(resp.content.decode("utf-8"))['Model'])
            text = response['make'] + ' ' +response['model'] + ':' + response['prob']
            car_list.append(text)
            #demo purpose
            prob_of_car = float(response['prob'])
            #draw rec and text
            if response['model'] not in valid_models:
                print_text = response['make'] + ' ' +response['model'] 
            else:
            #    cv2.rectangle(imgcv,
            #        (left, top), (right, bot),
            #        (128, 127, 77), thick//2)
            #    cv2.putText(imgcv, 'car', (left, top - 12),
            #        0, 1e-3 * h * 2 / 3, (128, 127, 77),thick//5)
            #    continue
                print_text = response['make'] + ' ' +response['model'] + ': $' + qq_price[response['model']]
            if prob_of_car > 0.95:
                cv2.rectangle(imgcv,
                    (left, top), (right, bot),
                    (56, 254, 0), thick//2)
                cv2.putText(imgcv, print_text, (left, top - 12),
                    0, 1e-3 * h * 2 / 3, (56, 254, 0),thick//5)
            elif prob_of_car < 0.7:
                cv2.rectangle(imgcv,
                    (left, top), (right, bot),
                    (128, 127, 77), thick//2)
                cv2.putText(imgcv, 'car', (left, top - 12),
                    0, 1e-3 * h * 2 / 3, (128, 127, 77),thick//5)

            else:
                cv2.rectangle(imgcv,
                    (left, top), (right, bot),
                    (255, 255, 153), thick//2)
                cv2.putText(imgcv, print_text,
                    (left, top - 12),0, 1e-3 * h * 2 / 3, (255, 255, 153),thick//5)
        else:
            print("only support cars")
            return

    video_output = 'test/out/video.txt'
    with open(video_output, 'a') as f:
        f.write(json.dumps(car_list) + '\t\n')

    #return image if in video
    return imgcv

    

    
    
def image_set(cfg, weights, dir):

    outfolder = 'test/out/'
    tmpfolder = 'test/out/tmp/'
    file_list = os.listdir(outfolder)
    tmp_list = os.listdir(tmpfolder)
    for f in file_list:
        if f.endswith('.jpg'):
            os.remove(outfolder  + f)
    for f in tmp_list:
        if f.endswith('tmp.jpg'):
            os.remove(tmpfolder  + f)

    image_list = os.listdir(dir)
    print(image_list)
    for im in image_list:
        image = cv2.imread(dir + im)
        print(type(image))
        if isinstance(image, np.ndarray):
            processed = dectect_cars_per_image(cfg, weights, image)
            
            img_name = 'test/out/' + os.path.splitext(os.path.basename(im))[0] + '.jpg'
            print(img_name)
            cv2.imwrite(img_name, processed)
                                                        
    
#image_set(sys.argv[1], sys.argv[2], sys.argv[3])
image_set('cfg/yolo-car.cfg', 'bin/yolo-car_6000.weights', 'test/')
# Out:
# ['street.mp4', 'maxresdefault.jpg', 'traffic-jam-getty.jpg', 'test_', 'IMG_20170424_111152.jpg', 'out', 'IMG_20170424_111147.jpg', 'IMG_20170424_111159.jpg', 'IMG_20170424_111123.jpg', 'IMG_20170424_111114.jpg', 'IMG_20170424_111141.jpg', 'IMG_20170424_111057.jpg', 'IMG_20170424_111106.jpg']
# <class 'NoneType'>
# <class 'numpy.ndarray'>
# Parsing cfg/yolo-car.cfg
# Loading bin/yolo-car_6000.weights ...
# Successfully identified 202314760 bytes
# Finished in 0.0139312744140625s
# /home/eason/workspace/car_detection/darkflow/darkflow/dark/darknet.py:54: UserWarning: ./cfg/yolo-car_6000.cfg not found, use cfg/yolo-car.cfg instead
#   cfg_path, FLAGS.model))
# [{'label': 'car', 'confidence': 0.94457632, 'topleft': {'x': 424, 'y': 357}, 'bottomright': {'x': 1800, 'y': 1033}}]
# test/out/maxresdefault.jpg
# <class 'numpy.ndarray'>
# Parsing cfg/yolo-car.cfg
# Loading bin/yolo-car_6000.weights ...
# Successfully identified 202314760 bytes
# Finished in 0.015151500701904297s
# [{'label': 'car', 'confidence': 0.65090048, 'topleft': {'x': 69, 'y': 0}, 'bottomright': {'x': 178, 'y': 51}}, {'label': 'car', 'confidence': 0.68521911, 'topleft': {'x': 245, 'y': 8}, 'bottomright': {'x': 342, 'y': 69}}, {'label': 'car', 'confidence': 0.60981405, 'topleft': {'x': 311, 'y': 4}, 'bottomright': {'x': 391, 'y': 56}}, {'label': 'car', 'confidence': 0.61553985, 'topleft': {'x': 465, 'y': 15}, 'bottomright': {'x': 545, 'y': 62}}, {'label': 'car', 'confidence': 0.62481791, 'topleft': {'x': 8, 'y': 36}, 'bottomright': {'x': 85, 'y': 126}}, {'label': 'car', 'confidence': 0.6103344, 'topleft': {'x': 147, 'y': 42}, 'bottomright': {'x': 240, 'y': 104}}, {'label': 'car', 'confidence': 0.60738653, 'topleft': {'x': 404, 'y': 40}, 'bottomright': {'x': 482, 'y': 94}}, {'label': 'car', 'confidence': 0.67090678, 'topleft': {'x': 442, 'y': 40}, 'bottomright': {'x': 531, 'y': 95}}, {'label': 'car', 'confidence': 0.71911025, 'topleft': {'x': 599, 'y': 41}, 'bottomright': {'x': 693, 'y': 89}}, {'label': 'car', 'confidence': 0.67521936, 'topleft': {'x': 232, 'y': 90}, 'bottomright': {'x': 333, 'y': 155}}, {'label': 'car', 'confidence': 0.76290059, 'topleft': {'x': 708, 'y': 86}, 'bottomright': {'x': 808, 'y': 149}}, {'label': 'car', 'confidence': 0.70441866, 'topleft': {'x': 89, 'y': 151}, 'bottomright': {'x': 190, 'y': 235}}, {'label': 'car', 'confidence': 0.69181406, 'topleft': {'x': 206, 'y': 149}, 'bottomright': {'x': 314, 'y': 226}}, {'label': 'car', 'confidence': 0.6767723, 'topleft': {'x': 353, 'y': 137}, 'bottomright': {'x': 477, 'y': 209}}, {'label': 'car', 'confidence': 0.75239956, 'topleft': {'x': 535, 'y': 148}, 'bottomright': {'x': 647, 'y': 221}}, {'label': 'car', 'confidence': 0.64515156, 'topleft': {'x': 757, 'y': 158}, 'bottomright': {'x': 845, 'y': 233}}, {'label': 'car', 'confidence': 0.7575683, 'topleft': {'x': 305, 'y': 201}, 'bottomright': {'x': 425, 'y': 282}}, {'label': 'car', 'confidence': 0.64414251, 'topleft': {'x': 209, 'y': 252}, 'bottomright': {'x': 336, 'y': 336}}, {'label': 'car', 'confidence': 0.64678735, 'topleft': {'x': 440, 'y': 252}, 'bottomright': {'x': 542, 'y': 329}}, {'label': 'car', 'confidence': 0.84156245, 'topleft': {'x': 586, 'y': 242}, 'bottomright': {'x': 704, 'y': 309}}, {'label': 'car', 'confidence': 0.75932425, 'topleft': {'x': 41, 'y': 302}, 'bottomright': {'x': 147, 'y': 381}}, {'label': 'car', 'confidence': 0.7420032, 'topleft': {'x': 202, 'y': 305}, 'bottomright': {'x': 323, 'y': 377}}, {'label': 'car', 'confidence': 0.76907212, 'topleft': {'x': 376, 'y': 307}, 'bottomright': {'x': 487, 'y': 390}}, {'label': 'car', 'confidence': 0.70036167, 'topleft': {'x': 528, 'y': 304}, 'bottomright': {'x': 652, 'y': 393}}, {'label': 'car', 'confidence': 0.79377156, 'topleft': {'x': 699, 'y': 307}, 'bottomright': {'x': 813, 'y': 369}}, {'label': 'car', 'confidence': 0.7233128, 'topleft': {'x': 869, 'y': 312}, 'bottomright': {'x': 982, 'y': 387}}, {'label': 'car', 'confidence': 0.74663359, 'topleft': {'x': 299, 'y': 357}, 'bottomright': {'x': 410, 'y': 450}}, {'label': 'car', 'confidence': 0.62208086, 'topleft': {'x': 521, 'y': 345}, 'bottomright': {'x': 629, 'y': 425}}, {'label': 'car', 'confidence': 0.62376583, 'topleft': {'x': 678, 'y': 347}, 'bottomright': {'x': 815, 'y': 444}}, {'label': 'car', 'confidence': 0.80149919, 'topleft': {'x': 41, 'y': 406}, 'bottomright': {'x': 169, 'y': 509}}, {'label': 'car', 'confidence': 0.64812821, 'topleft': {'x': 441, 'y': 408}, 'bottomright': {'x': 549, 'y': 492}}, {'label': 'car', 'confidence': 0.73439139, 'topleft': {'x': 606, 'y': 413}, 'bottomright': {'x': 722, 'y': 506}}, {'label': 'car', 'confidence': 0.64222354, 'topleft': {'x': 366, 'y': 451}, 'bottomright': {'x': 492, 'y': 539}}, {'label': 'car', 'confidence': 0.66844296, 'topleft': {'x': 431, 'y': 451}, 'bottomright': {'x': 546, 'y': 522}}, {'label': 'car', 'confidence': 0.65364981, 'topleft': {'x': 826, 'y': 455}, 'bottomright': {'x': 951, 'y': 539}}, {'label': 'car', 'confidence': 0.74713403, ...
# test/out/traffic-jam-getty.jpg
# <class 'NoneType'>
# <class 'numpy.ndarray'>
# Parsing cfg/yolo-car.cfg
# Loading bin/yolo-car_6000.weights ...
# Successfully identified 202314760 bytes
# Finished in 0.015103816986083984s
# [{'label': 'car', 'confidence': 0.71819204, 'topleft': {'x': 1338, 'y': 563}, 'bottomright': {'x': 1719, 'y': 764}}, {'label': 'car', 'confidence': 0.76132381, 'topleft': {'x': 1679, 'y': 599}, 'bottomright': {'x': 2267, 'y': 853}}, {'label': 'car', 'confidence': 0.69646162, 'topleft': {'x': 1877, 'y': 637}, 'bottomright': {'x': 2443, 'y': 899}}, {'label': 'car', 'confidence': 0.84475946, 'topleft': {'x': 2314, 'y': 661}, 'bottomright': {'x': 2971, 'y': 1090}}, {'label': 'car', 'confidence': 0.9263379, 'topleft': {'x': 76, 'y': 526}, 'bottomright': {'x': 2923, 'y': 3692}}]
# test/out/IMG_20170424_111152.jpg
# <class 'NoneType'>
# <class 'numpy.ndarray'>
# Parsing cfg/yolo-car.cfg
# Loading bin/yolo-car_6000.weights ...
# Successfully identified 202314760 bytes
# Finished in 0.015653610229492188s
# [{'label': 'car', 'confidence': 0.87148398, 'topleft': {'x': 79, 'y': 577}, 'bottomright': {'x': 911, 'y': 1197}}, {'label': 'car', 'confidence': 0.88151991, 'topleft': {'x': 1001, 'y': 677}, 'bottomright': {'x': 1964, 'y': 1109}}, {'label': 'car', 'confidence': 0.71805, 'topleft': {'x': 813, 'y': 487}, 'bottomright': {'x': 3023, 'y': 3652}}]
# test/out/IMG_20170424_111147.jpg
# <class 'numpy.ndarray'>
# Parsing cfg/yolo-car.cfg
# Loading bin/yolo-car_6000.weights ...
# Successfully identified 202314760 bytes
# Finished in 0.015291452407836914s
# [{'label': 'car', 'confidence': 0.63149339, 'topleft': {'x': 1889, 'y': 601}, 'bottomright': {'x': 2975, 'y': 1085}}, {'label': 'car', 'confidence': 0.83494014, 'topleft': {'x': 2, 'y': 835}, 'bottomright': {'x': 562, 'y': 1255}}, {'label': 'car', 'confidence': 0.69200945, 'topleft': {'x': 733, 'y': 844}, 'bottomright': {'x': 1361, 'y': 1148}}, {'label': 'car', 'confidence': 0.93357587, 'topleft': {'x': 254, 'y': 956}, 'bottomright': {'x': 2848, 'y': 3554}}]
# test/out/IMG_20170424_111159.jpg
# <class 'numpy.ndarray'>
# Parsing cfg/yolo-car.cfg
# Loading bin/yolo-car_6000.weights ...
# Successfully identified 202314760 bytes
# Finished in 0.015573740005493164s
# [{'label': 'car', 'confidence': 0.84896523, 'topleft': {'x': 587, 'y': 656}, 'bottomright': {'x': 1383, 'y': 1075}}, {'label': 'car', 'confidence': 0.84858799, 'topleft': {'x': 1899, 'y': 415}, 'bottomright': {'x': 2974, 'y': 1261}}, {'label': 'car', 'confidence': 0.89817655, 'topleft': {'x': 169, 'y': 830}, 'bottomright': {'x': 2845, 'y': 3041}}]
# test/out/IMG_20170424_111123.jpg
# <class 'numpy.ndarray'>
# Parsing cfg/yolo-car.cfg
# Loading bin/yolo-car_6000.weights ...
# Successfully identified 202314760 bytes
# Finished in 0.015378952026367188s
# [{'label': 'car', 'confidence': 0.64239311, 'topleft': {'x': 693, 'y': 544}, 'bottomright': {'x': 1080, 'y': 782}}, {'label': 'car', 'confidence': 0.66167921, 'topleft': {'x': 1102, 'y': 628}, 'bottomright': {'x': 1501, 'y': 835}}, {'label': 'car', 'confidence': 0.72914213, 'topleft': {'x': 1453, 'y': 713}, 'bottomright': {'x': 1915, 'y': 934}}, {'label': 'car', 'confidence': 0.8310132, 'topleft': {'x': 1931, 'y': 744}, 'bottomright': {'x': 2836, 'y': 1225}}, {'label': 'car', 'confidence': 0.80372757, 'topleft': {'x': 2614, 'y': 927}, 'bottomright': {'x': 3023, 'y': 1652}}, {'label': 'car', 'confidence': 0.93252534, 'topleft': {'x': 132, 'y': 725}, 'bottomright': {'x': 2913, 'y': 4018}}]
# test/out/IMG_20170424_111114.jpg
# <class 'numpy.ndarray'>
# Parsing cfg/yolo-car.cfg
# Loading bin/yolo-car_6000.weights ...
# Successfully identified 202314760 bytes
# Finished in 0.015598535537719727s
# [{'label': 'car', 'confidence': 0.72376102, 'topleft': {'x': 1683, 'y': 493}, 'bottomright': {'x': 2077, 'y': 679}}, {'label': 'car', 'confidence': 0.77851886, 'topleft': {'x': 59, 'y': 292}, 'bottomright': {'x': 680, 'y': 1186}}, {'label': 'car', 'confidence': 0.8210327, 'topleft': {'x': 1955, 'y': 551}, 'bottomright': {'x': 2645, 'y': 864}}, {'label': 'car', 'confidence': 0.72393125, 'topleft': {'x': 2657, 'y': 709}, 'bottomright': {'x': 3022, 'y': 1046}}, {'label': 'car', 'confidence': 0.93437773, 'topleft': {'x': 148, 'y': 402}, 'bottomright': {'x': 2899, 'y': 3235}}]
# test/out/IMG_20170424_111141.jpg
# <class 'numpy.ndarray'>
# Parsing cfg/yolo-car.cfg
# Loading bin/yolo-car_6000.weights ...
# Successfully identified 202314760 bytes
# Finished in 0.015515804290771484s
# [{'label': 'car', 'confidence': 0.71430343, 'topleft': {'x': 0, 'y': 341}, 'bottomright': {'x': 630, 'y': 1143}}, {'label': 'car', 'confidence': 0.70000345, 'topleft': {'x': 810, 'y': 543}, 'bottomright': {'x': 1229, 'y': 796}}, {'label': 'car', 'confidence': 0.69542444, 'topleft': {'x': 1262, 'y': 622}, 'bottomright': {'x': 1617, 'y': 871}}, {'label': 'car', 'confidence': 0.92974216, 'topleft': {'x': 146, 'y': 842}, 'bottomright': {'x': 2924, 'y': 3350}}]
# test/out/IMG_20170424_111057.jpg
# <class 'numpy.ndarray'>
# Parsing cfg/yolo-car.cfg
# Loading bin/yolo-car_6000.weights ...
# Successfully identified 202314760 bytes
# Finished in 0.015321969985961914s
# [{'label': 'car', 'confidence': 0.70568556, 'topleft': {'x': 2737, 'y': 894}, 'bottomright': {'x': 3004, 'y': 1704}}, {'label': 'car', 'confidence': 0.9448452, 'topleft': {'x': 220, 'y': 1153}, 'bottomright': {'x': 2851, 'y': 3332}}]
# test/out/IMG_20170424_111106.jpg
